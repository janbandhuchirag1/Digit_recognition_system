# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('resources/train.csv')

# %%
data = np.array(data)
m,n = data.shape
np.random.shuffle(data)
# Out:
# (42000, 785)
